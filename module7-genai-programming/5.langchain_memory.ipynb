# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from azure_openai_llm import create_azure_llm

from dotenv import load_dotenv
load_dotenv()

llm = create_azure_llm()

agent = create_agent(llm)

# %%
from langchain.messages import HumanMessage
from pprint import pprint

question = HumanMessage(content="Hello my name is Ali and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)
pprint(response["messages"][-1].content)
# Out:
# ("Hello, Ali! It's nice to meet you. Green is a beautiful color—it's often "
#  'associated with nature, growth, and tranquility. Do you have a favorite '
#  'shade of green?')

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response["messages"][-1].content)
# Out:
# ("I don't have access to personal information about you, including your "
#  "favorite color. However, if you'd like to share it or give me some hints, "
#  "I'd be happy to discuss it!")

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    llm,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Ali and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ("Hello, Ali! It's great to meet you. Green is a lovely color—it's often "
#  'associated with nature, growth, and tranquility. Do you have a favorite '
#  'shade of green or something specific you like about it?')

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response["messages"][-1].content)
# Out:
# 'Your favorite color is green!'
