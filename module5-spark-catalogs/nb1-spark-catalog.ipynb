# %%
from pyspark.sql import SparkSession

spark = SparkSession \
            .builder \
            .appName("Spark Catalog Demo") \
            .master("spark://spark-master:7077") \
            .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/opt/spark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2.5.2/cache
# The jars for the packages stored in: /root/.ivy2.5.2/jars
# io.delta#delta-spark_2.13 added as a dependency
# org.apache.spark#spark-connect_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3eca25d7-10e8-47a7-b85c-7ed68bbfc585;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.13;4.0.1 in central
# 	found io.delta#delta-storage;4.0.1 in central
# 	found org.antlr#antlr4-runtime;4.13.1 in central
# 	found org.apache.spark#spark-connect_2.13;4.1.1 in central
# 	found org.apache.spark#spark-pipelines_2.13;4.1.1 in central
# 	found org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 in central
# 	found jakarta.servlet#jakarta.servlet-api;5.0.0 in central
# 	found javax.servlet#javax.servlet-api;4.0.1 in central
# 	found com.google.guava#guava;33.4.8-jre in central
# 	found com.google.guava#failureaccess;1.0.3 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found org.jspecify#jspecify;1.0.0 in central
# 	found com.google.errorprone#error_prone_annotations;2.36.0 in central
# 	found com.google.j2objc#j2objc-annotations;3.0.0 in central
# 	found org.spark-project.spark#unused;1.0.0 in central
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-connect_2.13/4.1.1/spark-connect_2.13-4.1.1.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-connect_2.13;4.1.1!spark-connect_2.13.jar (2544ms)
# downloading https://repo1.maven.org/maven2/org/apache/spark/spark-pipelines_2.13/4.1.1/spark-pipelines_2.13-4.1.1.jar ...
# 	[SUCCESSFUL ] org.apache.spark#spark-pipelines_2.13;4.1.1!spark-pipelines_2.13.jar (359ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/guava/33.4.8-jre/guava-33.4.8-jre.jar ...
# 	[SUCCESSFUL ] com.google.guava#guava;33.4.8-jre!guava.jar(bundle) (486ms)
# downloading https://repo1.maven.org/maven2/com/google/guava/failureaccess/1.0.3/failureaccess-1.0.3.jar ...
# 	[SUCCESSFUL ] com.google.guava#failureaccess;1.0.3!failureaccess.jar (228ms)
# downloading https://repo1.maven.org/maven2/org/jspecify/jspecify/1.0.0/jspecify-1.0.0.jar ...
# 	[SUCCESSFUL ] org.jspecify#jspecify;1.0.0!jspecify.jar (226ms)
# downloading https://repo1.maven.org/maven2/com/google/errorprone/error_prone_annotations/2.36.0/error_prone_annotations-2.36.0.jar ...
# 	[SUCCESSFUL ] com.google.errorprone#error_prone_annotations;2.36.0!error_prone_annotations.jar (224ms)
# downloading https://repo1.maven.org/maven2/com/google/j2objc/j2objc-annotations/3.0.0/j2objc-annotations-3.0.0.jar ...
# 	[SUCCESSFUL ] com.google.j2objc#j2objc-annotations;3.0.0!j2objc-annotations.jar (227ms)
# :: resolution report :: resolve 17877ms :: artifacts dl 4306ms
# 	:: modules in use:
# 	com.google.errorprone#error_prone_annotations;2.36.0 from central in [default]
# 	com.google.guava#failureaccess;1.0.3 from central in [default]
# 	com.google.guava#guava;33.4.8-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;3.0.0 from central in [default]
# 	io.delta#delta-spark_2.13;4.0.1 from central in [default]
# 	io.delta#delta-storage;4.0.1 from central in [default]
# 	jakarta.servlet#jakarta.servlet-api;5.0.0 from central in [default]
# 	javax.servlet#javax.servlet-api;4.0.1 from central in [default]
# 	org.antlr#antlr4-runtime;4.13.1 from central in [default]
# 	org.apache.spark#spark-connect_2.13;4.1.1 from central in [default]
# 	org.apache.spark#spark-pipelines_2.13;4.1.1 from central in [default]
# 	org.jspecify#jspecify;1.0.0 from central in [default]
# 	org.scala-lang.modules#scala-parallel-collections_2.13;1.2.0 from central in [default]
# 	org.spark-project.spark#unused;1.0.0 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   15  |   7   |   7   |   0   ||   15  |   7   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3eca25d7-10e8-47a7-b85c-7ed68bbfc585
# 	confs: [default]
# 	7 artifacts copied, 8 already retrieved (17295kB/28ms)
# 26/02/23 18:26:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
print("Databases:")
spark.catalog.listDatabases()
# Out:
# Databases:
# [Database(name='default', catalog='spark_catalog', description='default database', locationUri='file:/opt/spark/work-dir/spark-warehouse')]

# %%
# 2. Create a Managed Table and an External Table
spark.sql("CREATE TABLE IF NOT EXISTS managed_test (id INT, data STRING)")
#spark.sql("CREATE TABLE IF NOT EXISTS external_test (id INT) LOCATION ''")

# 3. Use the Catalog to list tables and identify their types
tables = spark.catalog.listTables()
for t in tables:
    print(f"Table Name: {t.name} | Is Temporary: {t.isTemporary} | Table Type: {t.tableType}")
# Out:
# Table Name: managed_test | Is Temporary: False | Table Type: MANAGED

# %%
# 4. Cache a table and check its status via the Catalog
spark.catalog.cacheTable("managed_test")
is_cached = spark.catalog.isCached("managed_test")
print(f"Is 'managed_test' cached in memory? {is_cached}")

# 6. Uncache to free up cluster resources
spark.catalog.uncacheTable("managed_test")
# Out:
# Is 'managed_test' cached in memory? True
# 26/02/23 18:29:17 WARN CacheManager: Asked to cache already cached data.
