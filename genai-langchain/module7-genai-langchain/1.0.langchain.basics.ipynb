# %% [markdown]
# ## Environment Variables Setup (Required)
#
# ### Set in Terminal/PowerShell (Temporary - current session only)
# ```bash
# # Windows PowerShell
# $env:AZURE_OPENAI_API_KEY="your_api_key_here"
# $env:AZURE_OPENAI_ENDPOINT="https://your-resource-name.openai.azure.com/"
#
# # Windows Command Prompt
# set AZURE_OPENAI_API_KEY=your_api_key_here
# set AZURE_OPENAI_ENDPOINT=https://your-resource-name.openai.azure.com/
#
# # Linux/macOS
# export AZURE_OPENAI_API_KEY="your_api_key_here"
# export AZURE_OPENAI_ENDPOINT="https://your-resource-name.openai.azure.com/"
#
# ```
#
# ### Option: Use a `.env` file (Recommended)
# Create a `.env` file in your project root:
#
# ```env
# AZURE_OPENAI_API_KEY=your_api_key_here
# AZURE_OPENAI_ENDPOINT=https://your-resource-name.openai.azure.com/
# AZURE_OPENAI_API_VERSION=2023-03-15-preview
# ```
#
# Then ensure your notebook/script loads `.env` using `load_dotenv()` before creating the client.
# ```

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print("Current environment variables:")
print(f"AZURE_OPENAI_API_KEY: {'SET' if os.getenv('AZURE_OPENAI_API_KEY') else 'NOT SET'}")
print(f"AZURE_OPENAI_ENDPOINT: {'SET' if os.getenv('AZURE_OPENAI_ENDPOINT') else 'NOT SET'}")
print(f"AZURE_OPENAI_API_VERSION: {'SET' if os.getenv('AZURE_OPENAI_API_VERSION') else 'NOT SET'}")
# Out:
# Current environment variables:
# AZURE_OPENAI_API_KEY: SET
# AZURE_OPENAI_ENDPOINT: SET
# AZURE_OPENAI_API_VERSION: SET

# %% [markdown]
# ### 1. Development using LLM Native API

# %%
from openai import AzureOpenAI
from dotenv import load_dotenv  

load_dotenv()  # if using .env for configuration

client = AzureOpenAI(api_version="2023-03-15-preview")  # expects AZURE_OPENAI_API_KEY in your environment

topic = "LangChain"
response = client.chat.completions.create(
    model="lums-gpt-4.1-mini",
    temperature=0,
    messages=[
        {"role": "user", "content": f"Explain {topic} in 3 short bullet points."}
    ],
)

result = response.choices[0].message.content
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications with large language models (LLMs) by enabling easy integration of various components like prompts, chains, and memory.
# - It supports connecting LLMs with external data sources, APIs, and tools to create more dynamic and context-aware applications.
# - LangChain facilitates modular and scalable development of complex workflows involving language models, such as chatbots, question-answering systems, and document analysis.

# %% [markdown]
# ### 2. Developing using Langchain API

# %%
from langchain_openai import AzureChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# OPENAI_API_KEY and OPENAI_API_VERSION should be set in your environment or .env file
llm = AzureChatOpenAI(model="lums-gpt-4.1-mini")

# Basic Example 1: call the chat model directly
msg = llm.invoke("What is Python in one sentence?")
print("Example 1:\n", msg.content, "\n")
# Out:
# Example 1:
#  Python is a high-level, interpreted programming language known for its readability, simplicity, and versatility across various domains such as web development, data analysis, artificial intelligence, and automation.

# %% [markdown]
# ### 3. Creating Basic Chain using Langchain Expression Language (LCEL)

# %%
# Basic Example 2: simple prompt + parser chain
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in 3 short bullet points."
)

chain = prompt | llm | StrOutputParser()

result = chain.invoke({"topic": "LangChain"})
print(result)
# Out:
# - LangChain is a framework designed to simplify building applications with large language models (LLMs) by chaining together various components like prompts, models, and memory.
# - It enables developers to create complex workflows involving text generation, question answering, summarization, and more by combining modular building blocks.
# - LangChain supports integrations with external data sources and APIs, allowing LLMs to interact with real-world information dynamically.

# %%
# Basic Example 3: reuse your existing chain with different topics
for t in ["LangChain", "Prompt Engineering", "Vector Databases"]:
    print(f"Example 3 ({t}):")
    print(chain.invoke({"topic": t}))
    print("-" * 60)
# Out:
# Example 3 (LangChain):
# - **Framework for building applications with large language models (LLMs)** that enables easy integration, chaining, and management of multiple components like prompts, memory, and APIs.
# - **Supports modular and composable workflows**, allowing developers to create complex language model interactions by connecting simpler building blocks.
# - **Facilitates integration with external data sources and tools**, enhancing LLM capabilities for tasks such as document retrieval, question answering, and automation.
# ------------------------------------------------------------
# Example 3 (Prompt Engineering):
# - Designing clear and specific inputs to guide AI models in generating desired outputs.
# - Iteratively refining prompts to improve response accuracy and relevance.
# - Utilizing context, instructions, and examples to steer AI behavior effectively.
# ------------------------------------------------------------
# Example 3 (Vector Databases):
# - **Purpose:** Vector databases store and manage high-dimensional vector representations, often used for embedding data like text, images, or audio to enable similarity search.
# - **Functionality:** They perform efficient nearest neighbor searches on vectors to find related items based on distance metrics (e.g., cosine similarity).
# - **Use Cases:** Commonly used in AI applications such as recommendation systems, image retrieval, natural language processing, and anomaly detection.
# ------------------------------------------------------------
