# %%
import os

from langchain_openai import AzureChatOpenAI
from langchain.messages import HumanMessage

from dotenv import load_dotenv
from pprint import pprint

from azure_openai_llm import create_azure_llm

llm = create_azure_llm()

msg = [
    HumanMessage(content="What is the capital of the moon?")
]
response = llm.invoke(msg)
pprint(response.content)
# Out:
# Using chat deployment: lums-gpt-4.1-mini
# Endpoint: https://aoai-foundry-swc.openai.azure.com/
# API Version: 2025-01-01-preview
# ('The Moon does not have a capital because it is not a country or a political '
#  "entity. It is Earth's natural satellite and currently has no permanent "
#  "settlements or governments. If you're interested in lunar bases or colonies "
#  'proposed for the future, those are still in planning or conceptual stages.')

# %%
pprint(response.usage_metadata)
# Out:
# {'input_token_details': {'audio': 0, 'cache_read': 0},
#  'input_tokens': 15,
#  'output_token_details': {'audio': 0, 'reasoning': 0},
#  'output_tokens': 55,
#  'total_tokens': 70}

# %%
pprint(response.response_metadata)
# Out:
# {'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'},
#                             'protected_material_code': {'detected': False,
#                                                         'filtered': False},
#                             'protected_material_text': {'detected': False,
#                                                         'filtered': False},
#                             'self_harm': {'filtered': False,
#                                           'severity': 'safe'},
#                             'sexual': {'filtered': False, 'severity': 'safe'},
#                             'violence': {'filtered': False,
#                                          'severity': 'safe'}},
#  'finish_reason': 'stop',
#  'id': 'chatcmpl-DOGBFI3eYs8n2GC05MxihDXuVykor',
#  'logprobs': None,
#  'model_name': 'gpt-4.1-mini-2025-04-14',
#  'model_provider': 'openai',
#  'prompt_filter_results': [{'content_filter_results': {'hate': {'filtered': False,
#                                                                 'severity': 'safe'},
#                                                        'jailbreak': {'detected': False,
#                                                                      'filtered': False},
#                                                        'self_harm': {'filtered': False,
#                                                                      'severity': 'safe'},
#                                                        'sexual': {'filtered': False,
#                                                                   'severity': 'safe'},
#                                                        'violence': {'filtered': False,
#                                                                     'severity': 'safe'}},
#                             'prompt_index': 0}],
#  'system_fingerprint': 'fp_b6f445fc1c',
#  'token_usage': {'completion_tokens': 55,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 0,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 15,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 70}}

# %% [markdown]
# <H2>Create a basic Langchain Agent</h2>

# %%
from langchain.agents import create_agent

agent = create_agent(llm)
response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='db6dcfdf-f0e6-4800-9a30-4828de97b526'),
#               AIMessage(content="The Moon does not have a capital because it is not a country or a political entity. It is Earth's natural satellite and is not inhabited by humans. Therefore, it doesn't have a government or capital city. If you have any other questions about the Moon, feel free to ask!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 15, 'total_tokens': 72, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DOGCFjPnyzk5RGH8WWxpQvMIAzr1F', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019d32d7-e30c-7c73-83bb-288fd0006f23-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 57, 'total_tokens': 72, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Getting Last message in the array for the response</h2>

# %%
resp = response['messages'][-1].content
pprint(resp)
# Out:
# ('The Moon does not have a capital because it is not a country or a political '
#  "entity. It is Earth's natural satellite and is not inhabited by humans. "
#  "Therefore, it doesn't have a government or capital city. If you have any "
#  'other questions about the Moon, feel free to ask!')

# %% [markdown]
# <h2>Append Chat History/Setting Message Context</h2>

# %%
from langchain.messages import AIMessage

msg.clear()
msg.append(HumanMessage(content="What is the capital of the moon?"))
msg.append(AIMessage(content="The capital of the moon is Luna City."))
msg.append(HumanMessage(content="This is really great.  Can I go live there?"))

response = agent.invoke({"messages": msg })
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of the moon?', additional_kwargs={}, response_metadata={}, id='6cca5dcd-a41b-4f66-9e08-ce2f532dcb55'),
#               AIMessage(content='The capital of the moon is Luna City.', additional_kwargs={}, response_metadata={}, id='90355b86-b46d-433e-96cd-0fe8bc4f9efe', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='This is really great.  Can I go live there?', additional_kwargs={}, response_metadata={}, id='6f048551-2d12-4a68-92ac-84472fe0475c'),
#               AIMessage(content='Currently, there is no established city or permanent human settlement on the Moon, including a place called Luna City. While there are plans and ongoing discussions by space agencies and private companies about future lunar bases, living on the Moon is not yet possible for the general public. However, space exploration is advancing rapidly, so living on the Moon might become a reality in the future!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 75, 'prompt_tokens': 44, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-mini-2025-04-14', 'system_fingerprint': 'fp_b6f445fc1c', 'id': 'chatcmpl-DOGD4YqYX9RPCCh9XGjAUUSrkjKRX', 'prompt_filter_results': [{'prompt_index': 0, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'jailbreak': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}], 'finish_reason': 'stop', 'logprobs': None, 'content_filter_results': {'hate': {'filtered': False, 'severity': 'safe'}, 'protected_material_code': {'filtered': False, 'detected': False}, 'protected_material_text': {'filtered': False, 'detected': False}, 'self_harm': {'filtered': False, 'severity': 'safe'}, 'sexual': {'filtered': False, 'severity': 'safe'}, 'violence': {'filtered': False, 'severity': 'safe'}}}, id='lc_run--019d32d8-ab19-7653-aa44-3d0f39634a75-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 75, 'total_tokens': 119, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# <h2>Streaming Output</h2>

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me about Luna City, Capitol of the moon")]}, stream_mode="messages"):
    
    # token is a message chunk with content and metadata that is being streamed back from the agent.  
    # You can process it as it arrives.
    
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Luna City is a concept often envisioned as the first permanent human settlement on the Moon, sometimes described as the "capital of the Moon." Although it does not yet exist as a fully realized city, Luna City appears in various space exploration proposals, science fiction works, and plans for lunar colonization.
#
# ### Concept and Vision
# - **Purpose:** Luna City is imagined as a hub for scientific research, space exploration, and potentially as a center for lunar industry and tourism.
# - **Location:** Typically proposed to be located near the Moon's poles, especially the south pole, where there is near-permanent sunlight and access to water ice in shadowed craters.
# - **Population:** Early visions suggest a small, rotating crew of astronauts and scientists, eventually growing into a larger, self-sustaining population.
# - **Infrastructure:** Proposals include habitats built underground or covered with lunar regolith for radiation protection, life support systems, energy generation (solar power), and facilities for mining lunar resources.
#
# ### Real-World Projects Related to Luna City
# - **NASA Artemis Program:** Aiming to return humans to the Moon and establish a sustained presence, which could lay the groundwork for something like Luna City.
# - **International Lunar Gateway:** A planned lunar orbit space station that will serve as a staging point for lunar surface missions.
# - **Private and International Initiatives:** Companies like SpaceX and Blue Origin, as well as countries including China and Russia, have expressed interest in lunar bases that could evolve into lunar cities.
#
# ### In Popular Culture
# - Luna City has been depicted in various books, films, and games as a bustling lunar metropolis, often serving as a setting for stories about space colonization, politics, and human adaptation to extraterrestrial environments.
#
# ### Summary
# While Luna City as the "capital of the Moon" remains a futuristic idea, it represents humanity’s aspirations for permanent lunar settlement and exploration. The coming decades, driven by advances in space technology and international cooperation, may turn elements of this vision into reality.

# %% [markdown]
# <H2>System Prompt & Multi-Shot Prompting</h2>

# %%
# Must provide system prompt at the time of agent creation. 
# This is the instruction that will guide the agent's behavior.

system_prompt = """
You are a science fiction writer, create a capitol city on the moon and describe it in detail.
"""
agent = create_agent(llm, system_prompt=system_prompt)
response = agent.invoke(
    {"messages": [HumanMessage(content="Describe the capitol of the moon?")]}
)
print(response["messages"][-1].content)
# Out:
# Welcome to **Lunaris Prime**, the dazzling capitol city of the Moon, perched within the vast expanse of the Shackleton Crater near the lunar south pole.
#
# **City Overview:**
# Lunaris Prime is a sprawling metropolis encapsulated beneath an enormous, transparent geodesic dome made from ultra-resistant lunar glass, engineered to withstand micrometeorite impacts and cosmic radiation. The dome filters sunlight, creating a perpetual twilight glow that mimics Earth’s golden hour, bathing the city in warm, soothing light.
#
# **Architecture and Layout:**
# The city’s architecture is a harmonious blend of sleek, futuristic design and practical engineering adapted to lunar conditions. Buildings are constructed from lunar regolith composites, harvested and synthesized on-site to minimize Earth imports. Towers spiral upward, their surfaces embedded with solar nano-panels that track the sun’s movement, maximizing energy absorption.
#
# Lunaris Prime is arranged radially around the central hub known as the **Helios Spire**, a towering energy core that powers the city through a combination of fusion reactors and helium-3 harvesting operations. Radiating from this hub are sectors dedicated to governance, research, residential living, agriculture, and commerce, all interconnected by magnetic levitation transit tunnels that zip silently beneath the surface.
#
# **Environment and Life Support:**
# Inside the dome, artificial gravity is maintained through centripetal force on certain platforms, while the rest of the city relies on advanced magnetic boots and exoskeletons for mobility. Lush green parks filled with genetically engineered plants provide oxygen and psychological comfort, their bioluminescent flowers lighting pathways during the lunar night.
#
# Water is recycled with near-perfect efficiency, sourced from ice deposits in nearby craters and purified through advanced nanofiltration systems. The city also features massive vertical farms, hydroponic gardens, and algae bioreactors that sustain the population and contribute to carbon dioxide recycling.
#
# **Culture and Society:**
# Lunaris Prime is a melting pot of humanity’s brightest minds and diverse cultures, united by the shared mission of lunar colonization and exploration. The city hosts the **Lunar Council Chambers**, where representatives from Earth and lunar settlements debate and govern, ensuring peace and cooperation.
#
# Cultural venues abound: from zero-gravity theaters where performances defy traditional physics, to virtual reality arenas that simulate Earth’s lost natural wonders. Festivals celebrating the Earth-Moon connection are frequent, with holographic displays lighting the dome’s interior during special occasions.
#
# **Strategic Importance:**
# Beyond its role as the political and administrative heart of lunar activity, Lunaris Prime serves as a critical hub for research into space travel, lunar mining, and terraforming technologies. It’s also a pivotal waypoint for missions venturing deeper into the solar system, equipped with state-of-the-art spacecraft docks and repair facilities.
#
# ---
#
# Lunaris Prime stands as a beacon of human ingenuity and adaptability—a shining example of civilization thriving beyond Earth, blending technology, nature, and community on the silent, cratered face of the Moon.

# %%
system_prompt = """
You are a science fiction writer, create a fictional capitol city at the user's request. Please keep the below structure when responding to the user's request.

User: What is the capitol of Pakistan?
Response: Islamabad.
Weather: Humid

User: What is the capitol of Sun?
Response: Sunnyville.
Weather: Extremely hot

User: What is the capitol of the India?
Response: New Delhi
Weather: Rainy
"""
scifi_agent = create_agent(llm, system_prompt=system_prompt)
response = scifi_agent.invoke(
    {"messages": [HumanMessage(content="What is the capitol of the moon?")]}
)
print(response["messages"][1].content)
# Out:
# Response: Lunaris Prime
# Weather: Perpetual twilight with low gravity breezes and occasional shimmering dust storms
